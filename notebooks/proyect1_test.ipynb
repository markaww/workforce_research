# %% [markdown]
# # 1. Acquisition

# %%
from sqlalchemy import create_engine
import pandas as pd
import requests

def acquire():

    # 1/3 Connection to the db

    sqlitedb_rel_path = '../data/processed/raw_data_project_m1.db'
    conn_str = f'sqlite:///{sqlitedb_rel_path}'
    engine = create_engine(conn_str)

    # Use dBeaver to cleanup a few fields i.e. gender, then make a DataFrame:

    sql_query = """ 
    SELECT country_info.uuid,
           country_info.country_code,
           career_info.dem_education_level,
           career_info.normalized_job_code, 
           personal_info.age, 
           personal_info.gender,
           poll_info.question_bbi_2016wave4_basicincome_vote,
           poll_info.question_bbi_2016wave4_basicincome_argumentsagainst,
       poll_info.question_bbi_2016wave4_basicincome_argumentsfor 
    FROM country_info
    JOIN career_info ON country_info.uuid = career_info.uuid
    JOIN personal_info ON personal_info.uuid = career_info.uuid
    JOIN poll_info ON poll_info.uuid = personal_info.uuid
    """

    poll_db = pd.read_sql_query(sql_query, engine)

    poll_job_code = poll_db['normalized_job_code'].unique().tolist()

    # 2/3 Extract job skills and description table using APIs
    # Make a list with job ids from the csv, and use it to get job names from website (open skills api)

    poll_db = pd.read_sql_query(sql_query, engine)

    poll_job_code = poll_db['normalized_job_code'].unique().tolist()

    url_list = []
    for i in poll_job_code:
        url_list.append(f'http://api.dataatwork.org/v1/jobs/{i}/related_skills')

    # Make a DataFrame with the collection of results.

    lst = []
    for url in url_list:
        response = requests.get(url)
        json_data = response.json()
        lst.append(json_data)

    api_skills = pd.DataFrame(lst)

    # Remove nulls

    api_skills.drop(index=api_skills[api_skills.skills.isnull()].index, inplace=True)

    #Formula to get the first skill, which is always the one with highest 'importance' value

    def get_max(x):
        top_skill = pd.json_normalize(x).iloc[0]['skill_name']
        return top_skill

    api_skills['top_skill'] = api_skills['skills'].apply(get_max)

    # 3/3 Get country names with web scraping

    url = 'https://ec.europa.eu/eurostat/statistics-explained/index.php/Glossary:Country_codes'
    html = requests.get(url).content

    # Make the soup

    from bs4 import BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')

    # Assign the correct [0] table data to variable tablle

    table = soup.find_all('table')[0]

    # Remove anything that isn't countries or acronyms

    items = [x.text for x in table.find_all('td')]

    # Create a dict of 2 lists (countries and their acronyms), and convert to DF

    countries = []
    acronyms = []
    for i in items:
        if i.startswith('('):
            acronyms.append(i[1:-2])
        else:
            countries.append(i[:-1])

    raw_dict = {'countries': countries, 'acronyms': acronyms}

    # This dict, however is not exactly the right shape for a latter pd.replace,

    raw_dict_df = pd.DataFrame(raw_dict)
    new_dict = raw_dict_df.set_index('acronyms').to_dict()
    countries_dict = new_dict['countries']

    # Adjust a couple keys missing in the countries table

    countries_dict['GB'] = 'Great Britain'
    countries_dict['GR'] = 'Greece'
    del countries_dict['EL']

    # From wrangling, include the lines to lead to a single table output
    # Merge poll file with api job list

    poll_api_merge = poll_db.merge(api_skills, left_on='normalized_job_code', right_on='job_uuid')

    # Map countries from countries_dict

    poll_api_merge_countries = poll_api_merge.fillna('Unemployed').replace({"country_code": countries_dict})
    
    poll_api_merge_countries['dem_education_level'] = poll_api_merge_countries['dem_education_level'].str.replace('Unemployed','no')

    return poll_api_merge_countries

# %%
aquired_result = acquire()
aquired_result
# Out:
#                                    uuid country_code dem_education_level  \
# 0  54f0f1c0-dda1-0133-a559-0a81e8b09a82      Austria                high
# 1  cf24ed60-da3f-0133-0034-0a81e8b09a82      Austria                high
# 2  9ffc7390-dba5-0133-259b-0a81e8b09a82      Belgium                high
# 3  a6361230-da58-0133-cd5a-0a81e8b09a82      Belgium              medium
# 4  1e2b4750-d987-0133-3c7c-0a81e8b09a82     Bulgaria                high
#
#                 normalized_job_code           age  gender  \
# 0  861a9b9151e11362eb3c77ca914172d0  57 years old    male
# 1  861a9b9151e11362eb3c77ca914172d0  48 years old  female
# 2  861a9b9151e11362eb3c77ca914172d0  43 years old    male
# 3  861a9b9151e11362eb3c77ca914172d0  43 years old    male
# 4  861a9b9151e11362eb3c77ca914172d0  52 years old  female
#
#   question_bbi_2016wave4_basicincome_vote  \
# 0            I would probably vote for it
# 1                     I would vote for it
# 2                     I would vote for it
# 3        I would probably vote against it
# 4            I would probably vote for it
#
#   question_bbi_2016wave4_basicincome_argumentsagainst  \
# 0          It might encourage people to stop working
# 1                                  None of the above
# 2               It increases dependence on the state
# 3  Only the people who need it most should get so...
# 4          It might encourage people to stop working
#
#      question_bbi_2016wave4_basicincome_argumentsfor       error  \
# 0  It increases appreciation for household work a...  Unemployed
# 1  It reduces anxiety about financing basic needs...  Unemployed
# 2  It reduces anxiety about financing basic needs...  Unemployed
# 3                                  None of the above  Unemployed
# 4     It reduces anxiety about financing basic needs  Unemployed
#
#                            job_uuid                          job_title  \
# 0  861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
# 1  861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
# 2  861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
# 3  861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
# 4  861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
#
#                 normalized_job_title  \
# 0  automatic data processing planner
# 1  automatic data processing planner
# 2  automatic data processing planner
# 3  automatic data processing planner
# 4  automatic data processing planner
#
#                                               skills  \
# 0  [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# 1  [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# 2  [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# 3  [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# 4  [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
#
#                    top_skill
# 0  computers and electronics
# 1  computers and electronics
# 2  computers and electronics
# 3  computers and electronics
# 4  computers and electronics

# %%
aquired_result
# Out:
#                                       uuid country_code dem_education_level  \
# 0     54f0f1c0-dda1-0133-a559-0a81e8b09a82      Austria                high
# 1     cf24ed60-da3f-0133-0034-0a81e8b09a82      Austria                high
# 2     9ffc7390-dba5-0133-259b-0a81e8b09a82      Belgium                high
# 3     a6361230-da58-0133-cd5a-0a81e8b09a82      Belgium              medium
# 4     1e2b4750-d987-0133-3c7c-0a81e8b09a82     Bulgaria                high
# ...                                    ...          ...                 ...
# 5105  1cb1aac0-d94c-0133-8baa-0a81e8b09a82        Italy                high
# 5106  c8c33390-da69-0133-063a-0a81e8b09a82       Poland              medium
# 5107  d27d24d0-d9b1-0133-03d4-0a81e8b09a82       Poland                high
# 5108  529f3080-d99a-0133-1b7b-0a81e8b09a82     Portugal                  no
# 5109  0349c9d0-d9a1-0133-a38c-0a81e8b09a82     Portugal                high
#
#                    normalized_job_code           age  gender  \
# 0     861a9b9151e11362eb3c77ca914172d0  57 years old    male
# 1     861a9b9151e11362eb3c77ca914172d0  48 years old  female
# 2     861a9b9151e11362eb3c77ca914172d0  43 years old    male
# 3     861a9b9151e11362eb3c77ca914172d0  43 years old    male
# 4     861a9b9151e11362eb3c77ca914172d0  52 years old  female
# ...                                ...           ...     ...
# 5105  4cee16550636e292b8d136486fce943b  58 years old    male
# 5106  4cee16550636e292b8d136486fce943b  44 years old    male
# 5107  4cee16550636e292b8d136486fce943b  24 years old    male
# 5108  4cee16550636e292b8d136486fce943b  40 years old    male
# 5109  4cee16550636e292b8d136486fce943b  47 years old    male
#
#      question_bbi_2016wave4_basicincome_vote  \
# 0               I would probably vote for it
# 1                        I would vote for it
# 2                        I would vote for it
# 3           I would probably vote against it
# 4               I would probably vote for it
# ...                                      ...
# 5105            I would probably vote for it
# 5106                     I would vote for it
# 5107                     I would vote for it
# 5108            I would probably vote for it
# 5109            I would probably vote for it
#
#      question_bbi_2016wave4_basicincome_argumentsagainst  \
# 0             It might encourage people to stop working
# 1                                     None of the above
# 2                  It increases dependence on the state
# 3     Only the people who need it most should get so...
# 4             It might encourage people to stop working
# ...                                                 ...
# 5105  Only the people who need it most should get so...
# 5106  It might encourage people to stop working | It...
# 5107                                  None of the above
# 5108                        It is impossible to finance
# 5109  It might encourage people to stop working | On...
#
#         question_bbi_2016wave4_basicincome_argumentsfor       error  \
# 0     It increases appreciation for household work a...  Unemployed
# 1     It reduces anxiety about financing basic needs...  Unemployed
# 2     It reduces anxiety about financing basic needs...  Unemployed
# 3                                     None of the above  Unemployed
# 4        It reduces anxiety about financing basic needs  Unemployed
# ...                                                 ...         ...
# 5105  It reduces anxiety about financing basic needs...  Unemployed
# 5106     It reduces anxiety about financing basic needs  Unemployed
# 5107  It reduces anxiety about financing basic needs...  Unemployed
# 5108  It encourages financial independence and self-...  Unemployed
# 5109  It increases solidarity, because it is funded ...  Unemployed
#
#                               job_uuid                          job_title  \
# 0     861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
# 1     861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
# 2     861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
# 3     861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
# 4     861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
# ...                                ...                                ...
# 5105  4cee16550636e292b8d136486fce943b                 Data Capture Clerk
# 5106  4cee16550636e292b8d136486fce943b                 Data Capture Clerk
# 5107  4cee16550636e292b8d136486fce943b                 Data Capture Clerk
# 5108  4cee16550636e292b8d136486fce943b                 Data Capture Clerk
# 5109  4cee16550636e292b8d136486fce943b                 Data Capture Clerk
#
#                    normalized_job_title  \
# 0     automatic data processing planner
# 1     automatic data processing planner
# 2     automatic data processing planner
# 3     automatic data processing planner
# 4     automatic data processing planner
# ...                                 ...
# 5105                 data capture clerk
# 5106                 data capture clerk
# 5107                 data capture clerk
# 5108                 data capture clerk
# 5109                 data capture clerk
#
#                                                  skills  \
# 0     [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# 1     [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# 2     [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# 3     [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# 4     [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# ...                                                 ...
# 5105  [{'skill_uuid': '162cb662c7ef4dc9e86a2b5e88cbc...
# 5106  [{'skill_uuid': '162cb662c7ef4dc9e86a2b5e88cbc...
# 5107  [{'skill_uuid': '162cb662c7ef4dc9e86a2b5e88cbc...
# 5108  [{'skill_uuid': '162cb662c7ef4dc9e86a2b5e88cbc...
# 5109  [{'skill_uuid': '162cb662c7ef4dc9e86a2b5e88cbc...
#
#                       top_skill
# 0     computers and electronics
# 1     computers and electronics
# 2     computers and electronics
# 3     computers and electronics
# 4     computers and electronics
# ...                         ...
# 5105                   clerical
# 5106                   clerical
# 5107                   clerical
# 5108                   clerical
# 5109                   clerical
#
# [5110 rows x 15 columns]

# %% [markdown]
# ## Bonus 2

# %%
from sqlalchemy import create_engine
import pandas as pd
import requests

sqlitedb_rel_path = '../data/processed/raw_data_project_m1.db'
conn_str = f'sqlite:///{sqlitedb_rel_path}'
engine = create_engine(conn_str)

# Use dBeaver to cleanup a few fields i.e. gender, then make a DataFrame:

sql_query = """ 
SELECT country_info.uuid,
        country_info.country_code,
        career_info.dem_education_level,
        career_info.normalized_job_code, 
        personal_info.age, 
        personal_info.gender,
        poll_info.question_bbi_2016wave4_basicincome_vote,
        poll_info.question_bbi_2016wave4_basicincome_argumentsagainst,
        poll_info.question_bbi_2016wave4_basicincome_argumentsfor 
FROM country_info
JOIN career_info ON country_info.uuid = career_info.uuid
JOIN personal_info ON personal_info.uuid = career_info.uuid
JOIN poll_info ON poll_info.uuid = personal_info.uuid
"""

poll_db = pd.read_sql_query(sql_query, engine)

poll_job_code = poll_db['normalized_job_code'].unique().tolist()

url_list = []
for i in poll_job_code:
    url_list.append(f'http://api.dataatwork.org/v1/jobs/{i}/related_skills')

# Make a DataFrame with the collection of results.

lst = []
for url in url_list:
    response = requests.get(url)
    json_data = response.json()
    lst.append(json_data)

api_skills = pd.DataFrame(lst)
    
# Remove nulls 

api_skills.drop(index=api_skills[api_skills.skills.isnull()].index, inplace=True)

#Formula to get the first skill, which is always the one with highest 'importance' value

def get_max(x):
    top_skill = pd.json_normalize(x).iloc[0]['skill_name']
    return top_skill

api_skills['top_skill'] = api_skills['skills'].apply(get_max)

api_skills
# Out:
#     error                          job_uuid  \
# 1     NaN  861a9b9151e11362eb3c77ca914172d0
# 2     NaN  049a3f3a2b5f85cb2971ba77ad66e10c
# 3     NaN  f4b2fb1aa40f661488e2782b6d57ad2f
# 4     NaN  27af8700f5577cec835acee2cb90a2ff
# 5     NaN  c1b670eba9ccb65e7c99f7da116d5b9c
# ..    ...                               ...
# 152   NaN  b0fa6ede410f50b82ab74f5a705fe699
# 153   NaN  559a21f836c93876f31b60e6d10656a7
# 154   NaN  c1fb1a01b78373ac2153c66fa08d16dc
# 155   NaN  05bb9a333a66d6eb151e253623efe1c0
# 156   NaN  4cee16550636e292b8d136486fce943b
#
#                              job_title               normalized_job_title  \
# 1    Automatic Data Processing Planner  automatic data processing planner
# 2                     Data Coordinator                   data coordinator
# 3                   Database Developer                 database developer
# 4                Data Entry Specialist              data entry specialist
# 5                   Database Architect                 database architect
# ..                                 ...                                ...
# 152              Analytical Data Miner              analytical data miner
# 153            Data Analysis Assistant            data analysis assistant
# 154             Data Examination Clerk             data examination clerk
# 155                   Data Entry Clerk                   data entry clerk
# 156                 Data Capture Clerk                 data capture clerk
#
#                                                 skills
# 1    [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# 2    [{'skill_uuid': 'e1a8c649e57ad7b1cfeef1aad5ba5...
# 3    [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# 4    [{'skill_uuid': '162cb662c7ef4dc9e86a2b5e88cbc...
# 5    [{'skill_uuid': 'b3cb1294905e001d3d611bff1de39...
# ..                                                 ...
# 152  [{'skill_uuid': '20784bf09c9fe614603ad635e6093...
# 153  [{'skill_uuid': 'e72f8046dc4d704b6d1ca41dada93...
# 154  [{'skill_uuid': '500018df958f2b9f8b387cf5637a0...
# 155  [{'skill_uuid': '162cb662c7ef4dc9e86a2b5e88cbc...
# 156  [{'skill_uuid': '162cb662c7ef4dc9e86a2b5e88cbc...
#
# [140 rows x 5 columns]

# %%
bonus_2 = api_skills[['job_title', 'top_skill']]
bonus_2
# Out:
#                              job_title                  top_skill
# 1    Automatic Data Processing Planner  computers and electronics
# 2                     Data Coordinator       information ordering
# 3                   Database Developer  computers and electronics
# 4                Data Entry Specialist                   clerical
# 5                   Database Architect  computers and electronics
# ..                                 ...                        ...
# 152              Analytical Data Miner          critical thinking
# 153            Data Analysis Assistant     mathematical reasoning
# 154             Data Examination Clerk           english language
# 155                   Data Entry Clerk                   clerical
# 156                 Data Capture Clerk                   clerical
#
# [140 rows x 2 columns]

# %% [markdown]
# ## Bonus 2 wrangling

# %%
columns = ['dem_education_level', 'top_skill']
bonus_2 = aquired_result[columns]



bonus_2_grouped = bonus_2.groupby('dem_education_level').agg(list).reset_index()
bonus_2
# Out:
#      dem_education_level                  top_skill
# 0                   high  computers and electronics
# 1                   high  computers and electronics
# 2                   high  computers and electronics
# 3                 medium  computers and electronics
# 4                   high  computers and electronics
# ...                  ...                        ...
# 5105                high                   clerical
# 5106              medium                   clerical
# 5107                high                   clerical
# 5108                  no                   clerical
# 5109                high                   clerical
#
# [5110 rows x 2 columns]

# %% [markdown]
# ## Bonus 2 analysis

# %%
from collections import Counter

def counter(x):
    return dict(Counter(x))

bonus_2_grouped['top_skill'] = bonus_2_grouped['top_skill'].apply(counter)

bonus_2_grouped
# Out:
#   dem_education_level                                          top_skill
# 0                high  {'computers and electronics': 1659, 'informati...
# 1                 low  {'computers and electronics': 513, 'informatio...
# 2              medium  {'computers and electronics': 1458, 'informati...
# 3                  no  {'computers and electronics': 246, 'informatio...

# %%
def get_tops(x):
    tops = sorted(x, key=x.get, reverse=True)[:10]
    return tops 
    
bonus_2_grouped['top_10_skills'] = bonus_2_grouped['top_skill'].apply(get_tops)

columns = ['dem_education_level', 'top_10_skills']
final = bonus_2_grouped[columns]

final
# Out:
#   dem_education_level                                      top_10_skills
# 0                high  [computers and electronics, geography, clerica...
# 1                 low  [computers and electronics, clerical, geograph...
# 2              medium  [computers and electronics, geography, informa...
# 3                  no  [computers and electronics, geography, english...
